# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahullnitp/wizard_Code/blob/master/Code_it!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##List comprehension with If else statement in python

# %%
data_L_R['mon_fri']=[1  for i in data_L_R['Dayofweek'] if (i==0 or i==4) else 0 ] # example to a cell in other colaboratory :link--"https://colab.research.google.com/drive/1DfYWPVk3HRSnDtGnEhINN15v4X_Osnng?authuser=1#scrollTo=OAYsx-Aix2F7&line=3&uniqifier=1"

# %% [markdown]
# The above code snippet will yield a syntax error! the correct way would be to put the whole if clause ahead of the for statement and that’s because the if statement is applied over the elements generated by the for clause. So, things will work fine this way

# %%
data_L_R['mon_fri']=[1 if (i==0 or i==4) else 0 for i in data_L_R['Dayofweek']  ]
